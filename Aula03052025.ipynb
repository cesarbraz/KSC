# %% [markdown]
# <a href="https://colab.research.google.com/github/cesarbraz/KSC/blob/master/Aula03052025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
print(time.ctime())
# Out:
# Sat May  3 12:39:55 2025

# %%
time.sleep(5)
print (time.ctime())
# Out:
# Sat May  3 12:40:00 2025

# %% [markdown]
# $\sqrt(3x-1)+(1+x)^2$
